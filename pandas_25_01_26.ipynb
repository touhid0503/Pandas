# %% [markdown]
# <a href="https://colab.research.google.com/github/touhid0503/Pandas/blob/main/pandas_25_01_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #library

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# #Series

# %%
A=pd.Series([1,2,3,4],index=['a',1,'c','ee'])
A
# Out:
# a     1
# 1     2
# c     3
# ee    4
# dtype: int64

# %%
print(A)
# Out:
# a     1
# 1     2
# c     3
# ee    4
# dtype: int64

# %%
A.ndim
# Out:
# 1

# %%
A.dtype
# Out:
# dtype('int64')

# %%
A.nbytes
# Out:
# 32

# %%
print(type(A))
# Out:
# <class 'pandas.core.series.Series'>

# %%
A.values
# Out:
# array([1, 2, 3, 4])

# %%
A.index
# Out:
# Index(['a', 1, 'c', 'ee'], dtype='object')

# %%
type(A.values)
# Out:
# numpy.ndarray

# %%
print(A['ee'])
# Out:
# 4

# %%
A['a':'c']
# Out:
# a    1
# 1    2
# c    3
# dtype: int64

# %%
A['a':]
# Out:
# a     1
# 1     2
# c     3
# ee    4
# dtype: int64

# %%
A[:'c']
# Out:
# a    1
# 1    2
# c    3
# dtype: int64

# %%
grads=pd.Series({'A':4,'B':3.5,'C':3,'D':2.5})

# %%
grads.values
# Out:
# array([4. , 3.5, 3. , 2.5])

# %%
grads.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
marks=pd.Series({'A':85,'B':75,'C':65,'D':55})

# %%
marks.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
marks.values
# Out:
# array([85, 75, 65, 55])

# %%
type(marks)
# Out:
# pandas.core.series.Series

# %%
type(marks.values)
# Out:
# numpy.ndarray

# %%
marks.dtype
# Out:
# dtype('int64')

# %%
marks.ndim
# Out:
# 1

# %%
marks.nbytes
# Out:
# 32

# %%
marks
# Out:
# A    85
# B    75
# C    65
# D    55
# dtype: int64

# %%
marks['B']
# Out:
# np.int64(75)

# %%
marks[0:2]
# Out:
# A    85
# B    75
# dtype: int64

# %%
marks[:2]
# Out:
# A    85
# B    75
# dtype: int64

# %%
marks[2:]
# Out:
# C    65
# D    55
# dtype: int64

# %%
marks[:-1]
# Out:
# A    85
# B    75
# C    65
# dtype: int64

# %%
marks[-1:]
# Out:
# D    55
# dtype: int64

# %% [markdown]
# #DataFrame

# %%
B=pd.DataFrame({'Marks':marks,'Grades':grads})

# %%
B
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
B.T
# Out:
#            A     B     C     D
# Marks   85.0  75.0  65.0  55.0
# Grades   4.0   3.5   3.0   2.5

# %% [markdown]
# #values

# %%
B.values
# Out:
# array([[85. ,  4. ],
#        [75. ,  3.5],
#        [65. ,  3. ],
#        [55. ,  2.5]])

# %%
B.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
print(type(B))
print(type(B.values))
print(type(B.values[1]))
print(type(B.values[0][0]))
print(type(B.values[0][1]))
print(B.values[0][0])
print(B.values[1][0])
print(B.values[0][1])
print(B.ndim)
print(B.Grades)
print(B.Marks)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# 85.0
# 75.0
# 4.0
# 2
# A    4.0
# B    3.5
# C    3.0
# D    2.5
# Name: Grades, dtype: float64
# A    85
# B    75
# C    65
# D    55
# Name: Marks, dtype: int64

# %%
print(B.dtypes)
# Out:
# Marks       int64
# Grades    float64
# dtype: object

# %%
B.values[2,1]
# Out:
# np.float64(3.0)

# %%
B.index[0]
# Out:
# 'A'

# %%
B.values[0]
# Out:
# array([85.,  4.])

# %%
B.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
B.columns[1]
# Out:
# 'Grades'

# %%
B.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
B.values[1:]
# Out:
# array([[75. ,  3.5],
#        [65. ,  3. ],
#        [55. ,  2.5]])

# %%
B.values[:2]
# Out:
# array([[85. ,  4. ],
#        [75. ,  3.5]])

# %%
B.values[:,1]
# Out:
# array([4. , 3.5, 3. , 2.5])

# %%
B.values[1,:]
# Out:
# array([75. ,  3.5])

# %%
B.values[:-1]
# Out:
# array([[85. ,  4. ],
#        [75. ,  3.5],
#        [65. ,  3. ]])

# %%
B.values[-1:]
# Out:
# array([[55. ,  2.5]])

# %%
B.values[1:3,1]
# Out:
# array([3.5, 3. ])

# %%
B['scalemarks']=100*(B['Marks']/90)

# %%
B
# Out:
#    Marks  Grades  scalemarks
# A     85     4.0   94.444444
# B     75     3.5   83.333333
# C     65     3.0   72.222222
# D     55     2.5   61.111111

# %%
del B['scalemarks']

# %%
B
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
B[B['Marks']>70]
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5

# %%
B['Marks']>70
# Out:
# A     True
# B     True
# C    False
# D    False
# Name: Marks, dtype: bool

# %% [markdown]
# #NaN

# %%
A=pd.DataFrame([{'a':1,'b':4},{'b':-3,'c':9}])

# %%
A
# Out:
#      a  b    c
# 0  1.0  4  NaN
# 1  NaN -3  9.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  4  0.0
# 1  0.0 -3  9.0

# %%
A.dropna?

# %%
A
# Out:
#      a  b    c
# 0  1.0  4  NaN
# 1  NaN -3  9.0
