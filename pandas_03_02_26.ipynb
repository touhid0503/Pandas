# %% [markdown]
# <a href="https://colab.research.google.com/github/touhid0503/Pandas/blob/main/pandas_03_02_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Example DataFrame

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Country': ['USA', 'Canada', 'UK']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35      UK

# %% [markdown]
# #Loading a DataFrame

# %%
#df = pd.read_csv('data.csv')        # Load from CSV
#df = pd.read_excel('data.xlsx')     # Load from Excel
#df = pd.DataFrame(data_dict)        # Load from dictionary

# %% [markdown]
# #Exploring a DataFrame

# %%
df.head()        # First 5 rows
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35      UK

# %%
df.tail()        # Last 5 rows
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35      UK

# %%
df.info()        # Column types and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Age      3 non-null      int64
#  2   Country  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()    # Summary stats
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df.columns       # Column names
# Out:
# Index(['Name', 'Age', 'Country'], dtype='object')

# %%
df.index         # Row indices
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([['Alice', 25, 'USA'],
#        ['Bob', 30, 'Canada'],
#        ['Charlie', 35, 'UK']], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# Country    object
# dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.values)
# Out:
# numpy.ndarray

# %% [markdown]
# #Accessing & Filtering Data

# %% [markdown]
# Basic Access

# %%
df['Age']                  # Single column
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df[['Name', 'Age']]        # Multiple columns
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df.iloc[0]                 # First row by position
# Out:
# Name       Alice
# Age           25
# Country      USA
# Name: 0, dtype: object

# %%
df.loc[0]                  # First row by label
# Out:
# Name       Alice
# Age           25
# Country      USA
# Name: 0, dtype: object

# %% [markdown]
# Conditional Filtering (Boolean masks)

# %%
df[df['Age'] > 30]                          # Age over 30
# Out:
#       Name  Age Country
# 2  Charlie   35      UK

# %%
df[df['Country'] == 'USA']                 # Country match
# Out:
#     Name  Age Country
# 0  Alice   25     USA

# %%
df[(df['Age'] > 25) & (df['Country'] == 'UK')]  # Multiple conditions
# Out:
#       Name  Age Country
# 2  Charlie   35      UK

# %% [markdown]
# Advanced Filtering

# %%
df[df['Name'].str.startswith('A')]         # Names starting with A
# Out:
#     Name  Age Country
# 0  Alice   25     USA

# %%
df[df['Country'].isin(['USA', 'UK'])]      # Match multiple values
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 2  Charlie   35      UK

# %%
df[~df['Country'].isin(['Canada'])]        # NOT condition
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 2  Charlie   35      UK

# %% [markdown]
# #CRUD Operations in Pandas

# %% [markdown]
# Create (Insert Rows)

# %%
new_row = pd.DataFrame([{'Name': 'Diana', 'Age': 28, 'Country': 'Germany'}])
df = pd.concat([df, new_row], ignore_index=True)

# %%
df
# Out:
#       Name  Age  Country
# 0    Alice   25      USA
# 1      Bob   30   Canada
# 2  Charlie   35       UK
# 3    Diana   28  Germany

# %% [markdown]
# Read (Access Data)

# %%
df.loc[df['Name'] == 'Alice']
# Out:
#     Name  Age Country
# 0  Alice   25     USA

# %%
df.iloc[2]
# Out:
# Name       Charlie
# Age             35
# Country         UK
# Name: 2, dtype: object

# %% [markdown]
# Update (Modify Values)

# %%
df.loc[df['Name'] == 'Bob', 'Age'] = 31             # Update Bob's age
df['Country'] = df['Country'].str.upper()           # Convert all country names to uppercase

# %%
df
# Out:
#       Name  Age  Country
# 0    Alice   25      USA
# 1      Bob   31   CANADA
# 2  Charlie   35       UK
# 3    Diana   28  GERMANY

# %% [markdown]
#  Delete (Drop Data)

# %%
df = df.drop(2, axis=0)                             # Drop row with index 2
df = df[df['Name'] != 'Alice']                      # Drop rows where name == Alice
df = df.drop('Age', axis=1)                         # Drop 'Age' column

# %%
df
# Out:
#     Name  Country
# 1    Bob   CANADA
# 3  Diana  GERMANY

# %% [markdown]
# #Cleaning Data

# %%
df.isnull().sum()                          # Count missing values
# Out:
# Name       0
# Country    0
# dtype: int64

# %%
#df.dropna(inplace=True)                   # Drop rows with missing values

# %%
#df.fillna({'Age': 0}, inplace=True)       # Fill missing Age values with 0

# %%
#df.isnull().sum()

# %%
df.rename(columns={'Name': 'name'}, inplace=True)   # Rename column

# %%
df
# Out:
#     name  Country
# 1    Bob   CANADA
# 3  Diana  GERMANY

# %%
df['name'] = df['name'].astype(object)   # Convert column to float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 1 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2 non-null      object
#  1   Country  2 non-null      object
# dtypes: object(2)
# memory usage: 48.0+ bytes

# %% [markdown]
# #Analyzing Data

# %%
df['Country'].value_counts()                       # Count occurrences
# Out:
# Country
# CANADA     1
# GERMANY    1
# Name: count, dtype: int64

# %%
#df.groupby('Country')['Age'].mean()                # Average age per country

# %%
df.sort_values(by='name', ascending=False)          # Sort by name descending
# Out:
#     name  Country
# 3  Diana  GERMANY
# 1    Bob   CANADA

# %% [markdown]
# #Saving Data

# %%
#df.to_csv('cleaned_data.csv', index=False)
#df.to_excel('output.xlsx', index=False)
