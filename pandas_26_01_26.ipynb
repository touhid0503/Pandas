# %% [markdown]
# <a href="https://colab.research.google.com/github/touhid0503/Pandas/blob/main/pandas_26_01_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Indexing

# %%
A=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
A
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
A['a':'c']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
A[0:3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
B=pd.Series(['A','B','D',],index=[1,3,4])
B
# Out:
# 1    A
# 3    B
# 4    D
# dtype: object

# %%
B[1]
# Out:
# 'A'

# %%
B[1:3] #implicit
# Out:
# 3    B
# 4    D
# dtype: object

# %%
B.loc[1:3] #explicit
# Out:
# 1    A
# 3    B
# dtype: object

# %%
B.iloc[1:3] #implicit
# Out:
# 3    B
# 4    D
# dtype: object

# %%
B.iloc[:-1]
# Out:
# 1    A
# 3    B
# dtype: object

# %%
Area=pd.Series({'California':423967,'Texas':695662,'New York':141297,'Florida':170312,'Illinois':149995})
Pop=pd.Series({'California':38332521,'Texas':26448193,'New York':19651127,'Florida':19552860,'Illinois':12882135})

# %%
C=pd.DataFrame({'area':Area,'pop':Pop},index=['California','Texas','New York','Florida','Illinois'])
C
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
C.iloc[2,:]
# Out:
# area      141297
# pop     19651127
# Name: New York, dtype: int64

# %%
C.loc['California',:]
# Out:
# area      423967
# pop     38332521
# Name: California, dtype: int64

# %%
C.loc[:,'area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
C.loc[::-1,:]
# Out:
#               area       pop
# Illinois    149995  12882135
# Florida     170312  19552860
# New York    141297  19651127
# Texas       695662  26448193
# California  423967  38332521

# %%
C.loc[:,::-1]
# Out:
#                  pop    area
# California  38332521  423967
# Texas       26448193  695662
# New York    19651127  141297
# Florida     19552860  170312
# Illinois    12882135  149995

# %% [markdown]
# #csv files

# %%
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('/content/mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.drop(['class','cap-shape'],inplace=True,axis=1)

# %%
df.head(5)
# Out:
#   cap-surface cap-color bruises odor gill-attachment gill-spacing gill-size  \
# 0           s         n       t    p               f            c         n
# 1           s         y       t    a               f            c         b
# 2           s         w       t    l               f            c         b
# 3           y         w       t    p               f            c         n
# 4           s         g       f    n               f            w         b
#
#   gill-color stalk-shape stalk-root  ... stalk-surface-below-ring  \
# 0          k           e          e  ...                        s
# 1          k           e          c  ...                        s
# 2          n           e          c  ...                        s
# 3          n           e          e  ...                        s
# 4          k           t          e  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
df.rename(columns={'cap-surface':'cap_surface','gill-attachment':'gill_attachment'},inplace=True)

# %%
df.head(5)
# Out:
#   cap_surface cap-color bruises odor gill_attachment gill-spacing gill-size  \
# 0           s         n       t    p               f            c         n
# 1           s         y       t    a               f            c         b
# 2           s         w       t    l               f            c         b
# 3           y         w       t    p               f            c         n
# 4           s         g       f    n               f            w         b
#
#   gill-color stalk-shape stalk-root  ... stalk-surface-below-ring  \
# 0          k           e          e  ...                        s
# 1          k           e          c  ...                        s
# 2          n           e          c  ...                        s
# 3          n           e          e  ...                        s
# 4          k           t          e  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
#df['Date']=pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#        cap_surface cap-color bruises  odor gill_attachment gill-spacing  \
# count         8124      8124    8124  8124            8124         8124
# unique           4        10       2     9               2            2
# top              y         n       f     n               f            c
# freq          3244      2284    4748  3528            7914         6812
#
#        gill-size gill-color stalk-shape stalk-root  ...  \
# count       8124       8124        8124       8124  ...
# unique         2         12           2          5  ...
# top            b          b           t          b  ...
# freq        5612       1728        4608       3776  ...
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# unique                        4                      9                      9
# top                           s                      w                      w
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap_surface               8124 non-null   object
#  1   cap-color                 8124 non-null   object
#  2   bruises                   8124 non-null   object
#  3   odor                      8124 non-null   object
#  4   gill_attachment           8124 non-null   object
#  5   gill-spacing              8124 non-null   object
#  6   gill-size                 8124 non-null   object
#  7   gill-color                8124 non-null   object
#  8   stalk-shape               8124 non-null   object
#  9   stalk-root                8124 non-null   object
#  10  stalk-surface-above-ring  8124 non-null   object
#  11  stalk-surface-below-ring  8124 non-null   object
#  12  stalk-color-above-ring    8124 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# cap_surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#df.fillna(0,inplace=True)

# %%
df.shape
# Out:
# (8124, 21)

# %%
df.duplicated().sum()
# Out:
# np.int64(4428)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3696, 21)

# %%
#df2=df.groupby('gill_attachment')[['population','habitat']].sum().reset_index()

# %%
#df3=df[df['gill_attachment']<1000]
